# %% [markdown]
# <a href="https://colab.research.google.com/github/sumityad07/AI-doctor_Assisent/blob/main/RockSMineral.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#laoding the file

# %%
sonar = pd.read_csv('/content/Copy of sonar data.csv',header=None)

# %%
sonar
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
sonar.shape
# Out:
# (208, 61)

# %%
X = sonar.drop(columns=60,axis=1)
Y = sonar[60]
X.shape
Y.shape
# Out:
# (208,)

# %%
X_train , X_test,Y_train,Y_test = train_test_split(sonar.drop(60,axis=1),sonar[60],test_size=0.2,random_state=1)

# %%
print(X.shape)
print(X_train.shape)
print(X_test.shape)
# Out:
# (208, 60)
# (166, 60)
# (42, 60)

# %%
model = LogisticRegression()
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_train,Y_train)
# Out:
# 0.8313253012048193

# %%
prediction = model.predict(X_test)

score = accuracy_score(prediction,Y_test)
print(score)
# Out:
# 0.8095238095238095

# %%
input_data =(0.1088,0.1278,0.0926,0.1234,0.1276,0.1731,0.1948,0.4262,0.6828,0.5761,0.4733,0.2362,0.1023,0.2904,0.4713,0.4659,0.1415,0.0849,0.3257,0.9007,0.9312,0.4856,0.1346,0.1604,0.2737,0.5609,0.3654,0.6139,0.5470,0.8474,0.5638,0.5443,0.5086,0.6253,0.8497,0.8406,0.8420,0.9136,0.7713,0.4882,0.3724,0.4469,0.4586,0.4491,0.5616,0.4305,0.0945,0.0794,0.0274,0.0154,0.0140,0.0455,0.0213,0.0082,0.0124,0.0167,0.0103,0.0205,0.0178,0.0187)

data_array = np.asarray(input_data)

data_reshaped = data_array.reshape(1,-1)

prediction = model.predict(data_reshaped)

if (prediction[0]=='R'):
  print('The object is a Rock')
else:
  print('The object is a mine')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2528200943.py in <cell line: 0>()
#       1 input_data =(0.1088,0.1278,0.0926,0.1234,0.1276,0.1731,0.1948,0.4262,0.6828,0.5761,0.4733,0.2362,0.1023,0.2904,0.4713,0.4659,0.1415,0.0849,0.3257,0.9007,0.9312,0.4856,0.1346,0.1604,0.2737,0.5609,0.3654,0.6139,0.5470,0.8474,0.5638,0.5443,0.5086,0.6253,0.8497,0.8406,0.8420,0.9136,0.7713,0.4882,0.3724,0.4469,0.4586,0.4491,0.5616,0.4305,0.0945,0.0794,0.0274,0.0154...
#       2
# ----> 3 data_array = np.asarray(input_data)
#       4
#       5 data_reshaped = data_array.reshape(1,-1)
#
# NameError: name 'np' is not defined

# %%
-
